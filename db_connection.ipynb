# %%
# Import Dependencies
import psycopg2
import pandas as pd
from sqlalchemy import create_engine

# Import PostgreSQL password
from config import db_password

# %%
# Create engine instance
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/carbon_db"
engine = create_engine(db_string)

# %%
# Connect to PostgreSQL server
dbConnection = engine.connect()

# %%
# Read data from historical_emissions table into a DataFrame
emissions_df = pd.read_sql("select * from \"historical_emissions\"", dbConnection)

# Display Dataframe
emissions_df.head(10)
# Out:
#   iso_code      country  year    co2  co2_per_capita  trade_co2  cement_co2  \
# 0      AFG  Afghanistan  1949  0.015           0.002        NaN         NaN
# 1      AFG  Afghanistan  1950  0.084           0.011        NaN         NaN
# 2      AFG  Afghanistan  1951  0.092           0.012        NaN         NaN
# 3      AFG  Afghanistan  1952  0.092           0.012        NaN         NaN
# 4      AFG  Afghanistan  1953  0.106           0.013        NaN         NaN
# 5      AFG  Afghanistan  1954  0.106           0.013        NaN         NaN
# 6      AFG  Afghanistan  1955  0.154           0.019        NaN         NaN
# 7      AFG  Afghanistan  1956  0.183           0.022        NaN         NaN
# 8      AFG  Afghanistan  1957  0.293           0.034        NaN         NaN
# 9      AFG  Afghanistan  1958  0.330           0.038        NaN         NaN
#
#    cement_co2_per_capita  coal_co2  coal_co2_per_capita  ...  \
# 0                    NaN     0.015                0.002  ...
# ...

# %%
for column in emissions_df.columns:
    if emissions_df[column].isnull().sum() > 3100:
        emissions_df = emissions_df.drop(column, axis=1)

# %%
for column in emissions_df.columns:
    print(f"Column {column} has {emissions_df[column].isnull().sum()} null values")
# Out:
# Column country has 0 null values
# Column year has 0 null values
# Column co2 has 1319 null values
# Column co2_per_capita has 1957 null values
# Column co2_growth_prct has 293 null values
# Column co2_growth_abs has 1695 null values
# Column cumulative_co2 has 1319 null values
# Column share_global_co2 has 1319 null values
# Column share_global_cumulative_co2 has 1319 null values
# Column population has 3097 null values

# %%
# Close the database connection
dbConnection.close();
