# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
temps_path = "annual_global_land_ocean_temps.csv"
temps_df = pd.read_csv(temps_path)
temps_df
# Out:
#      Year  Anomaly  Temperature (Celsius)
# 0    1880    -0.12                  13.78
# 1    1881    -0.08                  13.82
# 2    1882    -0.09                  13.81
# 3    1883    -0.18                  13.72
# 4    1884    -0.26                  13.64
# ..    ...      ...                    ...
# 137  2017     0.91                  14.81
# 138  2018     0.82                  14.72
# 139  2019     0.95                  14.85
# 140  2020     0.98                  14.88
# 141  2021     0.84                  14.74
#
# [142 rows x 3 columns]

# %%
#temps_df["Rolling Anomaly"] = temps_df["Anomaly"].rolling(10).mean()
#temps_df

# %%
emissions_path = "CO2_emissions_1990_2018_cleaned.csv"
emissions_df = pd.read_csv(emissions_path)
emissions_df
# Out:
#        World    China  United States    India  Indonesia    Japan   Russia  \
# 0   22849.92  1823.96        4426.40   341.32     832.39  1016.89  1790.34
# 1   23056.40  1952.78        4389.50   386.17     846.23  1029.99  1766.89
# 2   22988.29  2068.77        4461.62   409.09     855.30  1041.79  1630.98
# 3   23124.00  2294.12        4581.76   431.31     869.88  1033.99  1447.33
# 4   23260.29  2414.50        4654.52   466.79     881.31  1087.22  1238.41
# 5   23890.22  2735.48        4708.31   519.98     909.21  1097.10  1190.39
# 6   24214.92  2715.50        4864.46   555.60     772.38  1110.51  1159.83
# 7   25292.92  2779.27        5129.29   600.38    1484.56  1098.26  1052.50
# 8   24895.32  2882.75        5172.06   618.73     907.96  1055.50  1043.96
# 9   24957.30  2799.84        5191.66   683.00     849.42  1090.14  1081.87
# 10  25637.87  2994.73        5357.88   719.07     795.62  1107.18  1115.29
# ...

# %%
global_emissions = list(emissions_df["World"])
global_emissions
# Out:
# [22849.92,
#  23056.4,
#  22988.29,
#  23124.0,
#  23260.29,
#  23890.22,
#  24214.92,
#  25292.92,
#  24895.32,
#  24957.3,
#  25637.87,
#  25726.42,
#  26486.63,
#  27308.37,
#  28826.48,
#  29663.75,
#  30905.93,
#  31608.28,
#  31856.76,
#  31769.89,
#  33328.38,
#  33226.01,
#  33620.34,
#  34217.18,
#  34558.59,
#  34521.91,
#  35160.6,
#  35588.7,
#  36441.55]

# %%
temps_1990_2018 = temps_df[(temps_df["Year"] >= 1990) & (temps_df["Year"] <= 2018)]
temps_1990_2018["Emissions"] = global_emissions
temps_1990_2018
# Out:
# /Users/scwoody411/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      Year  Anomaly  Temperature (Celsius)  Emissions
# 110  1990     0.45                  14.35   22849.92
# 111  1991     0.39                  14.29   23056.40
# 112  1992     0.24                  14.14   22988.29
# 113  1993     0.28                  14.18   23124.00
# 114  1994     0.34                  14.24   23260.29
# 115  1995     0.47                  14.37   23890.22
# 116  1996     0.32                  14.22   24214.92
# 117  1997     0.51                  14.41   25292.92
# 118  1998     0.65                  14.55   24895.32
# ...

# %%
#plot_df = temps_1990_2018.set_index("Emissions")

temps_1990_2018.plot.scatter("Emissions", "Temperature (Celsius)")
# Out:
# <AxesSubplot:xlabel='Emissions', ylabel='Temperature (Celsius)'>

# %%
X = temps_1990_2018['Emissions'].values.reshape(-1, 1)
X.shape
# Out:
# (29, 1)

# %%
y = temps_1990_2018['Temperature (Celsius)']

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (29,)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
print(model.score(X, y))
# Out:
# [3.37491638e-05]
# 13.509483376448951
# 0.7105504690367337

# %%
# Take global carbon emissions predictions and use them to predict global surface temperature

# Find information on consequences of predicted global surface temperature rise
