# %%
import pandas as pd

# %%
# Read in land temperatures dataset
csv_path1 = "GlobalLandTemperaturesByCountry.csv"
df = pd.read_csv(csv_path1)
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty Country
# 0  1743-11-01               4.384                          2.294   Åland
# 1  1743-12-01                 NaN                            NaN   Åland
# 2  1744-01-01                 NaN                            NaN   Åland
# 3  1744-02-01                 NaN                            NaN   Åland
# 4  1744-03-01                 NaN                            NaN   Åland

# %%
# Create new column that converts the date from an objecct to datetime
df['datetime'] = pd.to_datetime(df['dt'])
df.dtypes
# Out:
# dt                                       object
# AverageTemperature                      float64
# AverageTemperatureUncertainty           float64
# Country                                  object
# datetime                         datetime64[ns]
# dtype: object

# %%
# Create new column that grabs the year from the datetime column
df["Year"] = df["datetime"].dt.to_period('Y')
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty Country  \
# 0  1743-11-01               4.384                          2.294   Åland
# 1  1743-12-01                 NaN                            NaN   Åland
# 2  1744-01-01                 NaN                            NaN   Åland
# 3  1744-02-01                 NaN                            NaN   Åland
# 4  1744-03-01                 NaN                            NaN   Åland
#
#     datetime  Year
# 0 1743-11-01  1743
# 1 1743-12-01  1743
# 2 1744-01-01  1744
# 3 1744-02-01  1744
# 4 1744-03-01  1744

# %%
# Filter for years 1990 and beyond to match carbon emissions dataset
df = df[df["Year"] >= "1990"]
df.head()
# Out:
#               dt  AverageTemperature  AverageTemperatureUncertainty Country  \
# 2954  1990-01-01               0.515                          0.359   Åland
# 2955  1990-02-01               3.350                          0.629   Åland
# 2956  1990-03-01               3.134                          0.231   Åland
# 2957  1990-04-01               4.846                          0.255   Åland
# 2958  1990-05-01               8.708                          0.378   Åland
#
#        datetime  Year
# 2954 1990-01-01  1990
# 2955 1990-02-01  1990
# 2956 1990-03-01  1990
# 2957 1990-04-01  1990
# 2958 1990-05-01  1990

# %%
# Get each country's average annual land temperature using groupby
df = df.groupby(["Country", "Year"]).mean()
df.reset_index(inplace=True)
df.head()
# Out:
#        Country  Year  AverageTemperature  AverageTemperatureUncertainty
# 0  Afghanistan  1990           14.993333                       0.362417
# 1  Afghanistan  1991           14.370750                       0.411000
# 2  Afghanistan  1992           14.056083                       0.501667
# 3  Afghanistan  1993           14.439250                       0.539250
# 4  Afghanistan  1994           14.754750                       0.396833

# %%
# Pivot DataFrame to make each year a column
df = df.pivot(index='Country', columns='Year', values='AverageTemperature')
df.reset_index(inplace=True)
df.rename_axis(None, axis = 1, inplace=True)
df.head()
# Out:
#           Country       1990       1991       1992       1993       1994  \
# 0     Afghanistan  14.993333  14.370750  14.056083  14.439250  14.754750
# 1          Africa  24.703750  24.422250  24.335417  24.538667  24.438750
# 2         Albania  13.468667  12.338833  13.084667  13.122583  14.099667
# 3         Algeria  24.014417  23.011083  22.767000  23.450833  23.642083
# 4  American Samoa  27.156250  27.171167  27.072000  26.816417  26.986333
#
#         1995       1996       1997       1998  ...       2004       2005  \
# 0  14.859167  14.426000  14.904000  15.132500  ...  15.770917  14.980000
# 1  24.718417  24.634500  24.706833  25.020500  ...  24.895917  25.156167
# 2  12.782083  12.736500  12.900917  13.311250  ...  13.258167  12.747083
# 3  23.722500  23.734333  23.955167  23.920583  ...  23.916000  24.222583
# 4  27.268667  27.112667  26.955750  27.424833  ...  27.281167  27.373500
#
#         2006       2007       2008       2009       2010       2011  \
# 0  15.595583  15.106167  15.216500  15.257750  15.828667  15.518000
# 1  24.818917  24.851500  24.754667  25.026500  25.472500  24.786500
# 2  12.976917  13.890500  13.955167  13.844250  13.775417  13.443250
# 3  24.200833  24.065333  23.950250  24.154333  25.215667  24.144167
# 4  27.081250  27.452417  26.995083  27.034250  27.453417  27.009500
#
#         2012       2013
# 0  14.481583  16.533625
# 1  24.725917  25.208750
# 2  13.768250  14.993875
# 3  23.954833  25.121500
# 4  27.201417  27.517250
#
# [5 rows x 25 columns]

# %%
# Save DataFrame as json file
df.to_json('clean_land_temps.json', orient='records')
